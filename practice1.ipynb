# %% [markdown]
# Calculate the sum of a list

# %%
list = [1,2,3,4]
b = 0
for i in list:
 b+= i
 
print(b)
# Out:
# 10

# %% [markdown]
# add the numbers 1 - 10

# %%
b=0
for i in range (1,11):
 b+= i
 
print(b)
# Out:
# 55
# 55

# %% [markdown]
# Write a function to calculate the sum of figit number 1 to N. N is the argument

# %%
def sum(N):
    b = 0
    for i in range (N+1):
        b+= i
    return b

sum(10)
# Out:
# 55
