# %%
print("Hello World")
# Out:
# Hello World

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
'This is Khushi'
# Out:
# 'This is Khushi'

# %%
"""This is Khushi
Hi 
Bye"""
# Out:
# 'This is Khushi\nHi \nBye'

# %%
#Comment

# %%
"We can even " + "add strings together"
# Out:
# 'We can even add strings together'

# %% [markdown]
# LISTS AND DICTIONARIES

# %%
#a list of strings 
["a", "b", "c"]
# Out:
# ['a', 'b', 'c']

# %%
#a list of ints
[1,2,3]
# Out:
# [1, 2, 3]

# %%
#list with a string, int, and float

["a", 2,3.14]
# Out:
# ['a', 2, 3.14]

# %%
#a list of lists with mixed types 
[["a","b"],[1,2],[1.0,2.0]]
# Out:
# [['a', 'b'], [1, 2], [1.0, 2.0]]

# %%
# a dictionary
{"Name":"Shaw"}
# Out:
# {'Name': 'Shaw'}

# %%
{"Name":"Shaw", "Age":29, "Interests":['AI', 'Music','Bread']}
# Out:
# {'Name': 'Shaw', 'Age': 29, 'Interests': ['AI', 'Music', 'Bread']}

# %%
[{"Name":"Shaw", "Age":29, "Interests":['AI', 'Music','Bread']},{"Name":"Ify", "Age":27, "Interests":['Marketing', 'YouTube','Shopping']},]
# Out:
# [{'Name': 'Shaw', 'Age': 29, 'Interests': ['AI', 'Music', 'Bread']},
#  {'Name': 'Ify', 'Age': 27, 'Interests': ['Marketing', 'YouTube', 'Shopping']}]

# %%
# nested dictionary

{"User": {"Name":"Shaw", "Age":29, "Interests":['AI', 'Music','Bread']},"Last_login":"2024-09-06","Membership_Tier":"Free"}
# Out:
# {'User': {'Name': 'Shaw', 'Age': 29, 'Interests': ['AI', 'Music', 'Bread']},
#  'Last_login': '2024-09-06',
#  'Membership_Tier': 'Free'}

# %%
# creating a variable 

user_name="Shaw"
print(user_name)
# Out:
# Shaw

# %%
#defining more vars

user_age = 20
user_interests = ['AI', 'Music','Bread']

print(f"{user_name} is {user_age} years old. His interests include {user_interests}")
# Out:
# Shaw is 20 years old. His interests include ['AI', 'Music', 'Bread']

# %%
user_dict = {"Name": user_name, "Age" : user_age, "Interests": user_interests}
print(f'{user_dict["Name"]} is {user_dict["Age"]} years old. His interests include {user_dict["Interests"]}')
# Out:
# Shaw is 20 years old. His interests include ['AI', 'Music', 'Bread']

# %%
user_dict = {"Name": user_name, "Age" : user_age, "Interests": user_interests}
print(f'{user_dict["Name"]} is {user_dict["Age"]} years old. His interests include {user_dict["Interests"][0]}')
# Out:
# Shaw is 20 years old. His interests include AI

# %%
b = 7

# %%
id(b)
# Out:
# 4564846760

# %%
id(7)
# Out:
# 4564846760

# %%
a = [1,2,3]
b=a
c = [1,2,3]
print(a is b)
print(a is c)
print(a == c)
# Out:
# True
# False
# True

# %%
id(a)
# Out:
# 4602553152
