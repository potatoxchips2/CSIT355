# %%
# %pip install ipython-sql==0.5.0

# %%
# %load_ext sql
# %sql sqlite:///basketball.db

# %%
# %%sql
# drop table if exists game;
# drop table if exists arena;
# create table game (
#     team    varchar primary key,
#     wins    integer,
#     losses  integer
# );
# create table arena (
#     arena   varchar primary key,
#     city    varchar,
#     team    varchar
#     Foreign key (team) references game
# );

# %%
# %sql

insert into game values('Boston Celtices', 53, 29);
insert into game values('New York Knicks',31, 51);
insert into game values('Brooklyn Nets',20, 62);
insert into game values('Huston Rockets', 65, 17);
insert into arena values('Barclays Center', 'Brooklyn', 'Brooklyn Nets');
insert into arena values('Madison Square Garden', 'New York', 'New York Knicks');
insert into arena values('TD Garden', 'Boston', 'Boston Celtices');
insert into arena values('United Center', 'Chicago', 'Chicago Bulls');

# %%
# %sql select * from arena;

# %%
# %sql 
SELECT G.team, A.arena 
FROM Game G 
LEFT JOIN Arena A on G.team = A.team;

# %%
# %%sql
# drop table if exists sailors;
# CREATE TABLE sailors (
#     sid     INTEGER PRIMARY KEY,
#     sname   VARCHAR(100),
#     rating  INTEGER CHECK (rating BETWEEN 1 AND 10),
#     age     REAL CHECK(age BETWEEN 0 AND 100)
# );

# %%
# %%sql
#
# insert into sailors values(22,'Dustin', 7, 45.0);
# insert into sailors values(29,'Brutus', 8, 33.0);
# insert into sailors values(31,'Lubber', 4, 55.5);
# insert into sailors values(32,'Andy', 8, 25.5);
# insert into sailors values(58, 'Rusty', 10, 35.0);
# insert into sailors values(64,'Horatio', 7, 35.0);
# insert into sailors values(71,'Zorba', 10, 16.0);
# insert into sailors values(85,'Art', 3, 25.5);
# insert into sailors values(95,'Bob', 5, 63.5);
